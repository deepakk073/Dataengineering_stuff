# %%
import apache_beam as beam
from apache_beam.io import ReadFromText
from apache_beam.io import WriteToText
from apache_beam.io.gcp.internal.clients import bigquery
from apache_beam.options.pipeline_options import PipelineOptions
with beam.Pipeline(options=PipelineOptions()) as p:
    table_schema={'fields':[{'name':'key','type':'STRING','mode':'NULLABLE'},
                           {'name':'value','type':'STRING','mode':'NULLABLE'}
                           ]}
    table_spec='XXXXXXXXXXX'

    def sum_val(tup):
        (key,val) = tup
        return {'key': key,'value': sum(val)}#'%s  - %d'%(key, sum(val))
    out= (
        p
        |"read fro txt " >>ReadFromText("F:\codebase\Dataengineering_stuff\Dataflow\\random.txt")
        |beam.FlatMap(lambda x: x.split(' '))
        |beam.Map(lambda x: (x,1))
        |beam.GroupByKey()
        |beam.Map(sum_val)
        |beam.Map(print)
        
       #|WriteToText("F:\codebase\Dataengineering_stuff\Dataflow\dee1.txt")
    )
   # out|beam.io.WriteToBigQuery(
    #table_spec,
    #schema=table_schema,
   # write_disposition=beam.io.BigQueryDisposition.WRITE_TRUNCATE,
    #create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED)
# Out:
# {'key': 'Examine', 'value': 1}
# {'key': 'she', 'value': 4}
# {'key': 'brother', 'value': 1}
# {'key': 'prudent', 'value': 1}
# {'key': 'add', 'value': 1}
# {'key': 'day', 'value': 2}
# {'key': 'ham.', 'value': 1}
# {'key': 'Far', 'value': 1}
# {'key': 'stairs', 'value': 2}
# {'key': 'now', 'value': 3}
# {'key': 'coming', 'value': 1}
# {'key': 'bed', 'value': 2}
# {'key': 'oppose', 'value': 1}
# {'key': 'hunted', 'value': 1}
# {'key': 'become', 'value': 1}
# {'key': 'his.', 'value': 1}
# {'key': 'You', 'value': 1}
# {'key': 'zealously', 'value': 1}
# {'key': 'departure', 'value': 2}
# {'key': 'had', 'value': 3}
# {'key': 'procuring', 'value': 2}
# {'key': 'suspicion.', 'value': 1}
# {'key': 'Books', 'value': 1}
# {'key': 'whose', 'value': 1}
# {'key': 'front', 'value': 1}
# {'key': 'would', 'value': 1}
# {'key': 'purse', 'value': 1}
# {'key': 'if', 'value': 3}
# {'key': 'be', 'value': 3}
# {'key': 'do', 'value': 5}
# {'key': 'decay.', 'value': 1}
# {'key': 'Quitting', 'value': 1}
# {'key': 'you', 'value': 3}
# {'key': 'way', 'value': 1}
# {'key': 'formerly', 'value': 1}
# {'key': 'disposed', 'value': 1}
# {'key': 'perceive', 'value': 1}
# {'key': 'ladyship', 'value': 1}
# {'key': 'are.', 'value': 1}
# {'key': 'Common', 'value': 1}
# {'key': 'turned', 'value': 2}
# {'key': 'boy', 'value': 2}
# {'key': 'direct', 'value': 2}
# {'key': 'and', 'value': 4}
# {'key': 'yet.', 'value': 1}
# {'key': '', 'value': 20}
# {'key': 'He', 'value': 1}
# {'key': 'went', 'value': 1}
# {'key': 'such', 'value': 1}
# {'key': 'dare', 'value': 1}
# {'key': 'good', 'value': 1}
# {'key': 'mr', 'value': 3}
# {'key': 'fact.', 'value': 1}
# {'key': 'The', 'value': 2}
# {'key': 'small', 'value': 1}
# {'key': 'own', 'value': 2}
# {'key': 'seven', 'value': 1}
# {'key': 'saved', 'value': 1}
# {'key': 'man', 'value': 1}
# {'key': 'age', 'value': 1}
# {'key': 'no', 'value': 3}
# {'key': 'offer.', 'value': 1}
# {'key': 'Suspicion', 'value': 1}
# {'key': 'did', 'value': 2}
# {'key': 'mrs', 'value': 1}
# {'key': 'nor', 'value': 3}
# {'key': 'furniture', 'value': 2}
# {'key': 'smallness.', 'value': 1}
# {'key': 'Scale', 'value': 1}
# {'key': 'whole', 'value': 1}
# {'key': 'downs', 'value': 1}
# {'key': 'often', 'value': 1}
# {'key': 'leave', 'value': 2}
# {'key': 'not', 'value': 1}
# {'key': 'eat.', 'value': 1}
# {'key': 'An', 'value': 2}
# {'key': 'expression', 'value': 1}
# {'key': 'reasonably', 'value': 1}
# {'key': 'cultivated', 'value': 2}
# {'key': 'indulgence', 'value': 2}
# {'key': 'he', 'value': 8}
# {'key': 'surrounded', 'value': 2}
# {'key': 'instrument.', 'value': 1}
# {'key': 'Gentleman', 'value': 1}
# {'key': 'eat', 'value': 2}
# {'key': 'consisted', 'value': 2}
# {'key': 'are', 'value': 3}
# {'key': 'pronounce', 'value': 1}
# {'key': 'distrusts.', 'value': 2}
# {'key': 'His', 'value': 1}
# {'key': 'followed', 'value': 1}
# {'key': 'carriage', 'value': 1}
# {'key': 'proposal', 'value': 1}
# {'key': 'entrance', 'value': 1}
# {'key': 'directly', 'value': 1}
# {'key': 'elegance.', 'value': 1}
# {'key': 'Greater', 'value': 1}
# {'key': 'for', 'value': 3}
# {'key': 'cottage', 'value': 3}
# {'key': 'gay', 'value': 1}
# {'key': 'parties', 'value': 1}
# {'key': 'natural.', 'value': 1}
# {'key': 'Remaining', 'value': 1}
# {'key': 'on', 'value': 4}
# {'key': 'discourse', 'value': 4}
# {'key': 'suspected', 'value': 1}
# {'key': 'perpetual.', 'value': 1}
# {'key': 'Power', 'value': 1}
# {'key': 'dried', 'value': 1}
# {'key': 'her', 'value': 4}
# {'key': 'taken', 'value': 1}
# {'key': 'place', 'value': 1}
# {'key': 'ought', 'value': 1}
# {'key': 'the.', 'value': 1}
# {'key': 'Four', 'value': 1}
# {'key': 'our', 'value': 2}
# {'key': 'ham', 'value': 2}
# {'key': 'west', 'value': 1}
# {'key': 'miss.', 'value': 1}
# {'key': 'Education', 'value': 1}
# {'key': 'shameless', 'value': 1}
# {'key': 'who', 'value': 2}
# {'key': 'middleton', 'value': 1}
# {'key': 'agreement', 'value': 1}
# {'key': 'how.', 'value': 1}
# {'key': 'We', 'value': 1}
# {'key': 'in', 'value': 6}
# {'key': 'found', 'value': 1}
# {'key': 'world', 'value': 1}
# {'key': 'chief', 'value': 1}
# {'key': 'is', 'value': 2}
# {'key': 'at', 'value': 7}
# {'key': 'means', 'value': 1}
# {'key': 'weeks', 'value': 1}
# {'key': 'smile.', 'value': 1}
# {'key': 'Your', 'value': 1}
# {'key': 'it', 'value': 3}
# {'key': 'to', 'value': 5}
# {'key': 'gave', 'value': 1}
# {'key': 'life', 'value': 2}
# {'key': 'whom', 'value': 1}
# {'key': 'as.', 'value': 1}
# {'key': 'Favourable', 'value': 1}
# {'key': 'dissimilar', 'value': 2}
# {'key': 'resolution', 'value': 1}
# {'key': 'led', 'value': 1}
# {'key': 'had.', 'value': 1}
# {'key': 'At', 'value': 1}
# {'key': 'play', 'value': 2}
# {'key': 'much', 'value': 1}
# {'key': 'time', 'value': 1}
# {'key': 'four', 'value': 1}
# {'key': 'many.', 'value': 1}
# {'key': 'Moonlight', 'value': 1}
# {'key': 'of', 'value': 4}
# {'key': 'situation', 'value': 1}
# {'key': 'so', 'value': 3}
# {'key': 'necessary', 'value': 1}
# {'key': 'therefore', 'value': 2}
# {'key': 'attending', 'value': 1}
# {'key': 'abilities.', 'value': 1}
# {'key': 'Calling', 'value': 1}
# {'key': 'looking', 'value': 1}
# {'key': 'enquire', 'value': 1}
# {'key': 'up', 'value': 2}
# {'key': 'me', 'value': 5}
# {'key': 'removal.', 'value': 1}
# {'key': 'Park', 'value': 1}
# {'key': 'fat', 'value': 2}
# {'key': 'does', 'value': 1}
# {'key': 'deal', 'value': 1}
# {'key': 'our.', 'value': 1}
# {'key': 'Procured', 'value': 1}
# {'key': 'sex', 'value': 4}
# {'key': 'material', 'value': 1}
# {'key': 'his', 'value': 2}
# {'key': 'offering', 'value': 1}
# {'key': 'humanity', 'value': 1}
# {'key': 'laughing', 'value': 1}
# {'key': 'moderate', 'value': 1}
# {'key': 'can.', 'value': 1}
# {'key': 'Unreserved', 'value': 1}
# {'key': 'nay', 'value': 2}
# {'key': 'admiration', 'value': 1}
# {'key': 'interested.', 'value': 1}
# {'key': 'Departure', 'value': 1}
# {'key': 'performed', 'value': 3}
# {'key': 'exquisite', 'value': 1}
# {'key': 'rapturous', 'value': 1}
# {'key': 'ye', 'value': 1}
# {'key': 'resources.', 'value': 1}
# {'key': 'Greatest', 'value': 1}
# {'key': 'properly', 'value': 2}
# {'key': 'off', 'value': 2}
# {'key': 'exercise', 'value': 1}
# {'key': 'all.', 'value': 1}
# {'key': 'Unsatiable', 'value': 1}
# {'key': 'invitation', 'value': 2}
# {'key': 'its', 'value': 4}
# {'key': 'possession', 'value': 2}
# {'key': 'off.', 'value': 1}
# {'key': 'All', 'value': 1}
# {'key': 'difficulty', 'value': 2}
# {'key': 'estimating', 'value': 1}
# {'key': 'unreserved', 'value': 1}
# {'key': 'increasing', 'value': 2}
# {'key': 'the', 'value': 2}
# {'key': 'solicitude.', 'value': 1}
# {'key': 'Rapturous', 'value': 1}
# {'key': 'see', 'value': 1}
# {'key': 'tolerably', 'value': 1}
# {'key': 'end', 'value': 1}
# {'key': 'attention', 'value': 1}
# {'key': 'unfeeling.', 'value': 1}
# {'key': 'On', 'value': 1}
# {'key': 'unpleasing', 'value': 1}
# {'key': 'principles', 'value': 2}
# {'key': 'alteration', 'value': 2}
# {'key': 'of.', 'value': 1}
# {'key': 'Be', 'value': 1}
# {'key': 'preferred', 'value': 1}
# {'key': 'determine', 'value': 1}
# {'key': 'collected.', 'value': 1}
# {'key': 'Him', 'value': 1}
# {'key': 'acuteness', 'value': 1}
# {'key': 'listening', 'value': 1}
# {'key': 'estimable', 'value': 2}
# {'key': 'law.', 'value': 1}
# {'key': 'Decisively', 'value': 1}
# {'key': 'occasional', 'value': 3}
# {'key': 'advantages', 'value': 1}
# {'key': 'delightful', 'value': 1}
# {'key': 'introduced.', 'value': 1}
# {'key': 'Like', 'value': 1}
# {'key': 'law', 'value': 4}
# {'key': 'mean', 'value': 2}
# {'key': 'form', 'value': 1}
# {'key': 'sang', 'value': 2}
# {'key': 'loud', 'value': 1}
# {'key': 'lady', 'value': 1}
# {'key': 'put.', 'value': 1}
# {'key': 'Led', 'value': 1}
# {'key': 'ask', 'value': 1}
# {'key': 'possible', 'value': 1}
# {'key': 'mistress', 'value': 1}
# {'key': 'relation', 'value': 1}
# {'key': 'elegance', 'value': 1}
# {'key': 'likewise', 'value': 1}
# {'key': 'debating.', 'value': 1}
# {'key': 'By', 'value': 1}
# {'key': 'message', 'value': 1}
# {'key': 'or', 'value': 4}
# {'key': 'am', 'value': 1}
# {'key': 'nothing', 'value': 1}
# {'key': 'amongst', 'value': 1}
# {'key': 'chiefly', 'value': 1}
# {'key': 'address.', 'value': 1}
# {'key': 'enable', 'value': 1}
# {'key': 'men', 'value': 1}
# {'key': 'depend', 'value': 1}
# {'key': 'highly.', 'value': 1}
# {'key': 'Ham', 'value': 1}
# {'key': 'windows', 'value': 1}
# {'key': 'sixteen', 'value': 1}
# {'key': 'inquiry', 'value': 1}
# {'key': 'fortune', 'value': 1}
# {'key': 'demands.', 'value': 1}
# {'key': 'Is', 'value': 2}
# {'key': 'upon', 'value': 1}
# {'key': 'fond', 'value': 1}
# {'key': 'must', 'value': 1}
# {'key': 'shew.', 'value': 1}
# {'key': 'Really', 'value': 1}
# {'key': 'county', 'value': 1}
# {'key': 'unable', 'value': 1}
# {'key': 'sister.', 'value': 1}
# {'key': 'Feet', 'value': 1}
# {'key': 'like', 'value': 2}
# {'key': 'six.', 'value': 1}
# {'key': 'Among', 'value': 1}
# {'key': 'built', 'value': 2}
# {'key': 'now.', 'value': 1}
# {'key': 'In', 'value': 3}
# {'key': 'table', 'value': 1}
# {'key': 'an', 'value': 1}
# {'key': 'rapid', 'value': 1}
# {'key': 'blush.', 'value': 1}
# {'key': 'Merits', 'value': 1}
# {'key': 'behind', 'value': 1}
# {'key': 'afraid', 'value': 1}
# {'key': 'warmly.', 'value': 1}
# {'key': 'post', 'value': 1}
# {'key': 'shot', 'value': 1}
# {'key': 'ye.', 'value': 1}
# {'key': 'There', 'value': 1}
# {'key': 'out', 'value': 2}
# {'key': 'child', 'value': 1}
# {'key': 'sir', 'value': 1}
# {'key': 'lived.', 'value': 1}
# {'key': 'Design', 'value': 1}
# {'key': 'uneasy', 'value': 1}
# {'key': 'season', 'value': 1}
# {'key': 'branch', 'value': 1}
# {'key': 'praise', 'value': 1}
# {'key': 'esteem.', 'value': 1}
# {'key': 'Abilities', 'value': 1}
# {'key': 'believing', 'value': 1}
# {'key': 'remaining', 'value': 2}
# {'key': 'no.', 'value': 1}
# {'key': 'Mistaken', 'value': 1}
# {'key': 'denoting', 'value': 1}
# {'key': 'dashwood', 'value': 1}
# {'key': 'as', 'value': 1}
# {'key': 'screened.', 'value': 1}
# {'key': 'Whence', 'value': 1}
# {'key': 'esteem', 'value': 1}
# {'key': 'easily', 'value': 1}
# {'key': 'on.', 'value': 1}
# {'key': 'Dissuade', 'value': 1}
# {'key': 'husbands', 'value': 1}
# {'key': 'disposal.', 'value': 1}
# {'key': 'Improved', 'value': 1}
# {'key': 'provided', 'value': 1}
# {'key': 'blessing', 'value': 1}
# {'key': 'may', 'value': 1}
# {'key': 'peculiar', 'value': 1}
# {'key': 'domestic.', 'value': 1}
# {'key': 'Sight', 'value': 1}
# {'key': 'house', 'value': 1}
# {'key': 'has', 'value': 2}
# {'key': 'never.', 'value': 1}
# {'key': 'No', 'value': 2}
# {'key': 'visited', 'value': 1}
# {'key': 'raising', 'value': 1}
# {'key': 'gravity', 'value': 1}
# {'key': 'outward', 'value': 1}
# {'key': 'subject', 'value': 1}
# {'key': 'my', 'value': 2}
# {'key': 'be.', 'value': 2}
# {'key': 'Hold', 'value': 1}
# {'key': 'tore', 'value': 1}
# {'key': 'park', 'value': 1}
# {'key': 'feet', 'value': 1}
# {'key': 'near', 'value': 1}
# {'key': 'case.', 'value': 1}
# {'key': 'Invitation', 'value': 1}
# {'key': 'understood', 'value': 1}
# {'key': 'sentiments', 'value': 1}
# {'key': 'insipidity', 'value': 1}
# {'key': 'inhabiting', 'value': 1}
# {'key': 'in.', 'value': 1}
# {'key': 'Off', 'value': 1}
# {'key': 'melancholy', 'value': 1}
# {'key': 'old.', 'value': 1}
# {'key': 'speedily', 'value': 1}
# {'key': 'kindness', 'value': 1}
# {'key': 'oh.', 'value': 1}
# {'key': 'Respect', 'value': 1}
# {'key': 'article', 'value': 1}
# {'key': 'painted', 'value': 1}
# {'key': 'offices', 'value': 1}
# {'key': 'parlors.', 'value': 1}
# {'key': 'Must', 'value': 1}
# {'key': 'with', 'value': 2}
# {'key': 'him', 'value': 2}
# {'key': 'from', 'value': 1}
# {'key': 'were', 'value': 1}
# {'key': 'more.', 'value': 1}
# {'key': 'eldest', 'value': 1}
# {'key': 'result', 'value': 1}
# {'key': 'should', 'value': 1}
# {'key': 'remark', 'value': 1}
# {'key': 'vanity', 'value': 1}
# {'key': 'square.', 'value': 1}
# {'key': 'Unpleasant', 'value': 1}
# {'key': 'especially', 'value': 1}
# {'key': 'assistance', 'value': 1}
# {'key': 'sufficient', 'value': 1}
# {'key': 'comparison', 'value': 1}
# {'key': 'inquietude.', 'value': 1}
# {'key': 'Branch', 'value': 1}
# {'key': 'one', 'value': 1}
# {'key': 'shy', 'value': 1}
# {'key': 'edward', 'value': 1}
# {'key': 'wonder', 'value': 1}
# {'key': 'horses.', 'value': 1}
# {'key': 'Devonshire', 'value': 1}
# {'key': 'discovered', 'value': 1}
# {'key': 'excellence', 'value': 1}
# {'key': 'preference.', 'value': 1}
# {'key': 'Objection', 'value': 1}
# {'key': 'Simplicity', 'value': 1}
# {'key': 'affronting', 'value': 1}
# {'key': 'inquietude', 'value': 1}
# {'key': 'sympathize', 'value': 1}
# {'key': 'age.', 'value': 1}
# {'key': 'She', 'value': 1}
# {'key': 'meant', 'value': 1}
# {'key': 'new', 'value': 1}
# {'key': 'their', 'value': 1}
# {'key': 'could', 'value': 1}
# {'key': 'defer', 'value': 1}
# {'key': 'child.', 'value': 1}
# {'key': 'lose', 'value': 1}
# {'key': 'quit', 'value': 1}
# {'key': 'dull.', 'value': 1}
# {'key': 'Admiration', 'value': 1}
# {'key': 'we', 'value': 1}
# {'key': 'frequently', 'value': 1}
# {'key': 'he.', 'value': 1}
# {'key': 'Remarkably', 'value': 1}
# {'key': 'too', 'value': 1}
# {'key': 'far', 'value': 1}
# {'key': 'especially.', 'value': 1}
# {'key': 'Known', 'value': 1}
# {'key': 'tiled', 'value': 1}
# {'key': 'but', 'value': 1}
# {'key': 'sorry', 'value': 1}
# {'key': 'joy', 'value': 1}
# {'key': 'balls.', 'value': 1}
# {'key': 'Bed', 'value': 1}
# {'key': 'sudden', 'value': 1}
# {'key': 'manner', 'value': 1}
# {'key': 'indeed', 'value': 1}
# {'key': 'feebly.', 'value': 1}
# {'key': 'Face', 'value': 1}
# {'key': 'need', 'value': 1}
# {'key': 'wife', 'value': 1}
# {'key': 'paid', 'value': 1}
# {'key': 'that', 'value': 1}
# {'key': 'applauded', 'value': 1}
# {'key': 'favourite', 'value': 1}
# {'key': 'dashwoods', 'value': 1}
# {'key': 'distrusts', 'value': 1}
# {'key': 'explained.', 'value': 1}
